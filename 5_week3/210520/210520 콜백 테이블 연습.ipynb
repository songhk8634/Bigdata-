# %%
import pandas as pd
import numpy as np
import cx_Oracle
from sqlalchemy import create_engine

import dash
import dash_table
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State

# %%
conn = create_engine('oracle://c##big:1234@localhost:1521/orcl')

# %%
df = pd.read_sql_query('''select * from all_tab_cols where owner = 'C##BIG'  ''',con=conn)

# %%
df.loc[df.table_name == 'TITANIC_MASTER',"column_name"]
# Out:
# 0     PASSENGERS
# 1    PASSENGERID
# Name: column_name, dtype: object

# %%
app = dash.Dash('__name__')
app.layout = html.Div(
    [
        dcc.Dropdown(
            id = 'my-dropdown',
            options = [{'label':i,'value':i} for i in df.table_name.unique()]
        ),
        html.Hr(),
        html.Br(),
        dash_table.DataTable(
            id = 'my-table',
            page_size = 6,
            style_cell={'minWidth': 95, 'maxWidth': 95, 'width': 9}
        )
    ]
)

# %%
@app.callback(
    Output('my-table','columns'),
    Output('my-table','data'),
    Input('my-dropdown','value')
)
def update_table(table_name):
    columns =[{'name':i.lower(),'id':i.lower()} for i in df.loc[df.table_name == table_name,"column_name"]]
    stmt = 'select * from {}'.format(table_name)
    table_df = pd.read_sql_query(stmt,con=conn)
    data = table_df.to_dict('records')
    return columns, data

# %%
app.run_server(host='192.168.0.7',port='7777')
# Out:
# Dash is running on http://192.168.0.7:7777/
#
# Dash is running on http://192.168.0.7:7777/
#
# Dash is running on http://192.168.0.7:7777/
#
# Dash is running on http://192.168.0.7:7777/
#
# Dash is running on http://192.168.0.7:7777/
#
# Dash is running on http://192.168.0.7:7777/
#
# Dash is running on http://192.168.0.7:7777/
#
# Dash is running on http://192.168.0.7:7777/
# INFO:__name__:Dash is running on http://192.168.0.7:7777/
#  * Serving Flask app "__name__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# INFO:werkzeug: * Running on http://192.168.0.7:7777/ (Press CTRL+C to quit)
# INFO:werkzeug:192.168.0.7 - - [20/May/2021 16:07:23] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:192.168.0.7 - - [20/May/2021 16:07:23] "GET /_dash-layout HTTP/1.1" 200 -
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://datahub.io/five-thirty-eight/alcohol-consumption/r/drinks.csv')

# %%
cl_country = df.country.str.replace('&','*')
cl_country=cl_country.str.replace("'",'**')
df['country']=cl_country

# %%
stmt2='insert into alcohol_consumption(country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol) values'
for i in df.index:
    print(stmt2,tuple(df.iloc[i,:].values),';')
# Out:
# insert into alcohol_consumption(country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol) values ('afghanistan', 0, 0, 0, 0.0) ;
# insert into alcohol_consumption(country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol) values ('albania', 89, 132, 54, 4.9) ;
# insert into alcohol_consumption(country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol) values ('algeria', 25, 0, 14, 0.7) ;
# insert into alcohol_consumption(country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol) values ('andorra', 245, 138, 312, 12.4) ;
# insert into alcohol_consumption(country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol) values ('angola', 217, 57, 45, 5.9) ;
# insert into alcohol_consumption(country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol) values ('antigua  barbuda', 102, 128, 45, 4.9) ;
# ...

# %%
## QUERY 1
df.loc[:,]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    afghanistan              0                0              0
# 1        albania             89              132             54
# 2        algeria             25                0             14
# 3        andorra            245              138            312
# 4         angola            217               57             45
# ..           ...            ...              ...            ...
# 188    venezuela            333              100              3
# 189      vietnam            111                2              1
# 190        yemen              6                0              0
# 191       zambia             32               19              4
# 192     zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
## QUERY 2
df.loc[:,[df.wine_servings,df.spirit_servings]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-2bb0b7c3ee0b> in <module>
#       1 ## QUERY 2
# ----> 2 df.loc[:,[df.wine_servings,df.spirit_servings]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
## QUERY 3
df.loc[df.wine_servings>45,:]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               albania             89              132             54
# 3               andorra            245              138            312
# 6             argentina            193               25            221
# 8             australia            261               72            212
# 9               austria            279               75            191
# 11              bahamas            122              176             51
# 16              belgium            295               84            212
# 25             bulgaria            231              252             94
# 32               canada            240              122            100
# 35                chile            130              124            172
# 40         cook islands              0              254             74
# 42              croatia            230               87            254
# ...

# %%
## DISTINCT -- UNIQUE
df.wine_servings.unique().size
((df.wine_servings).astype('str')+(df.beer_servings).astype('str')).unique().size
# Out:
# 172

# %%
## ORDER BY
df.country.sort_values(ascending=False)
# Out:
# 192       zimbabwe
# 191         zambia
# 190          yemen
# 189        vietnam
# 188      venezuela
#           ...
# 4           angola
# 3          andorra
# 2          algeria
# 1          albania
# 0      afghanistan
# Name: country, Length: 193, dtype: object

# %%
df.sort_values(['spirit_servings','country'],ascending=False)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 68              grenada            199              438             28
# 15              belarus            142              373             42
# 141  russian federation            247              326             73
# 73                haiti              1              326              1
# 144           st. lucia            171              315             71
# ..                  ...            ...              ...            ...
# 27              burundi             88                0              0
# 19               bhutan             23                0              0
# 13           bangladesh              0                0              0
# 2               algeria             25                0             14
# 0           afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol
# 68                           11.9
# 15                           14.4
# ...

# %%
# 
df.sort_values(['spirit_servings','country'],ascending=False)[[]]

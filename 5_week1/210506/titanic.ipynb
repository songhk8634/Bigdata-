# %%
import numpy as np
import pandas as pd

# %%
df_titanic=pd.read_csv('https://gist.githubusercontent.com/DariaAlekseeva/299611a0daa6008685f7/raw/b431eb200bcafd2eba68a11ccbc80d051d3eeba9/titanic.csv')

# %%
df_titanic.dtypes
# Out:
# PassengerId      int64
# Passengers      object
# Class            int64
# Name            object
# Sex             object
# Age             object
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_titanic['Passengers'].apply(str).map(len).max()
# Out:
# 8

# %%
df_titanic['Cabin'].fillna('',inplace=True)
df_titanic['Fare'].fillna('',inplace=True)
df_titanic['Embarked'].fillna('',inplace=True)    ## 결측값대체

# %%
df_titanic.isnull().sum()  ## 결측값 개수 구하는
# Out:
# PassengerId    0
# Passengers     0
# Class          0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic_del=df_titanic.Name.str.replace("'",' ')
df_titanic['Name']=titanic_del

# %%
stmt2='insert into titanic(PassengerId,Passengers,Class,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked) values'
for i in df_titanic.index:
    print(stmt2,tuple(df_titanic.iloc[i,:].values),';')
# Out:
# insert into titanic(PassengerId,Passengers,Class,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked) values (1, 'Perished', 3, 'Braund, Mr. Owen Harris', 'male', '19 - 40', 1, 0, 'A/5 21171', 7.25, '', 'S') ;
# insert into titanic(PassengerId,Passengers,Class,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked) values (2, 'Survived', 1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female', '19 - 40', 1, 0, 'PC 17599', 71.2833, 'C85', 'C') ;
# insert into titanic(PassengerId,Passengers,Class,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked) values (3, 'Survived', 3, 'Heikkinen, Miss. Laina', 'female', '19 - 40', 0, 0, 'STON/O2. 3101282', 7.925, '', 'S') ;
# insert into titanic(PassengerId,Passengers,Class,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked) values (4, 'Survived', 1, 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female', '19 - 40', 1, 0, '113803', 53.1, 'C123', 'S') ;
# ...

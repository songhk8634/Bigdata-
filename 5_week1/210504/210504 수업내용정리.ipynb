# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
df = pd.DataFrame(data['data'])
df.columns = data['feature_names']
df['target'] = data['target']

# %%
df['Species'] = np.where(df.target == 0,'setosa',\
                         np.where(df.target == 1,'versicolor','verginica'))

# %%
df.drop('target',axis=1,inplace=True)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        Species
# 0       setosa
# ...

# %%
type("1.")
# Out:
# str

# %%
np.array([12],dtype='int8').dtype
# Out:
# dtype('int8')

# %%
df.iloc[:,1].max()
# Out:
# 4.4

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        Species
# 0       setosa
# ...

# %%
x = []
a = 0
for i in range(len(df.Species)):
    x = list(df.iloc[i,:].values)
    x.insert(a,a+1)
    x.append(('insert into iris(sl,sw,pl,pw,sp) values',))

# %%
x = list(df.iloc[0,:].values)
x.insert(0,0)
x
# Out:
# [0, 5.1, 3.5, 1.4, 0.2, 'setosa']

# %%
x.insert(0,0)
tuple(x)
# Out:
# (0, 0, 4.9, 3.0, 1.4, 0.2, 'setosa')

# %%
a = 1
for i in range(len(df.Species)):
    x = list(df.iloc[i,:].values)
    x.insert(0,a)
    x = tuple(x)
    print('insert into iris(seq, sl,sw,pl,pw,sp) values',x,';')
    a += 1
# Out:
# insert into iris(seq, sl,sw,pl,pw,sp) values (1, 5.1, 3.5, 1.4, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (2, 4.9, 3.0, 1.4, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (3, 4.7, 3.2, 1.3, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (4, 4.6, 3.1, 1.5, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (5, 5.0, 3.6, 1.4, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (6, 5.4, 3.9, 1.7, 0.4, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (7, 4.6, 3.4, 1.4, 0.3, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (8, 5.0, 3.4, 1.5, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (9, 4.4, 2.9, 1.4, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (10, 4.9, 3.1, 1.5, 0.1, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (11, 5.4, 3.7, 1.5, 0.2, 'setosa') ;
# insert into iris(seq, sl,sw,pl,pw,sp) values (12, 4.8, 3.4, 1.6, 0.2, 'setosa') ;
# ...
